# %%
# !git clone https://github.com/120L021101/SRCNN.git
# !pwd

# %%
# download the dataset

# %% [markdown]
# ### Start Training

# %%
# !python SRCNN/train.py --train-file /content/91-image_x3.h5 --eval-file /content/Set5_x3.h5 --outputs-dir /content/output/ --scale 3 --lr 1e-4 --batch-size 16 --num-epochs 10 --num-workers 2 --seed 10021
